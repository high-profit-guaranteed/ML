# %% [markdown]
# 출처 : https://github.com/ukairia777/finance_sentiment_corpus

# %%
import numpy as np
import pandas as pd
import os
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import matplotlib.pyplot as plt

# %%
finance_data = pd.read_csv("finance_data.csv")
finance_data
print('총 샘플의 수 :',len(finance_data))
# Out:
# 총 샘플의 수 : 4846

# %%
finance_data
# Out:
#         labels                                           sentence  \
# 0      neutral  According to Gran, the company has no plans to...
# 1      neutral  Technopolis plans to develop in stages an area...
# 2     negative  The international electronic industry company ...
# 3     positive  With the new production plant the company woul...
# 4     positive  According to the company's updated strategy fo...
# ...        ...                                                ...
# 4841  negative  LONDON MarketWatch -- Share prices ended lower...
# 4842   neutral  Rinkuskiai's beer sales fell by 6.5 per cent t...
# 4843  negative  Operating profit fell to EUR 35.4 mn from EUR ...
# 4844  negative  Net sales of the Paper segment decreased to EU...
# 4845  negative  Sales in Finland decreased by 10.5 % in Januar...
#
#                                            kor_sentence
# 0     Gran에 따르면, 그 회사는 회사가 성장하고 있는 곳이지만, 모든 생산을 러시아로...
# 1     테크노폴리스는 컴퓨터 기술과 통신 분야에서 일하는 회사들을 유치하기 위해 10만 평...
# 2     국제 전자산업 회사인 엘코텍은 탈린 공장에서 수십 명의 직원을 해고했으며, 이전의 ...
# 3     새로운 생산공장으로 인해 회사는 예상되는 수요 증가를 충족시킬 수 있는 능력을 증가...
# 4     2009-2012년 회사의 업데이트된 전략에 따르면, Basware는 20% - 4...
# ...                                                 ...
# 4841  런던 마켓워치 -- 은행주의 반등이 FTSE 100지수의 약세를 상쇄하지 못하면서 ...
# 4842  린쿠스키아의 맥주 판매량은 416만 리터로 6.5% 감소했으며 카우노 알루스의 맥주...
# 4843  영업이익은 2007년 68.8 mn에서 35.4 mn으로 떨어졌으며, 선박 판매 이...
# 4844  페이퍼 부문 순매출은 2008년 2분기 241.1 mn에서 2009년 2분기 221...
# 4845   핀란드에서의 판매는 1월에 10.5% 감소한 반면, 국외에서의 판매는 17% 감소했다.
#
# [4846 rows x 3 columns]

# %%
le = LabelEncoder()
finance_data_labeled = finance_data.__deepcopy__() # deep copy 미사용시 finance data labeled 수정해도 finance data 같이 수정됨.
finance_data_labeled["labels"] = le.fit_transform(finance_data_labeled["labels"])
finance_data_labeled
# Out:
#       labels                                           sentence  \
# 0          1  According to Gran, the company has no plans to...
# 1          1  Technopolis plans to develop in stages an area...
# 2          0  The international electronic industry company ...
# 3          2  With the new production plant the company woul...
# 4          2  According to the company's updated strategy fo...
# ...      ...                                                ...
# 4841       0  LONDON MarketWatch -- Share prices ended lower...
# 4842       1  Rinkuskiai's beer sales fell by 6.5 per cent t...
# 4843       0  Operating profit fell to EUR 35.4 mn from EUR ...
# 4844       0  Net sales of the Paper segment decreased to EU...
# 4845       0  Sales in Finland decreased by 10.5 % in Januar...
#
#                                            kor_sentence
# 0     Gran에 따르면, 그 회사는 회사가 성장하고 있는 곳이지만, 모든 생산을 러시아로...
# 1     테크노폴리스는 컴퓨터 기술과 통신 분야에서 일하는 회사들을 유치하기 위해 10만 평...
# 2     국제 전자산업 회사인 엘코텍은 탈린 공장에서 수십 명의 직원을 해고했으며, 이전의 ...
# 3     새로운 생산공장으로 인해 회사는 예상되는 수요 증가를 충족시킬 수 있는 능력을 증가...
# 4     2009-2012년 회사의 업데이트된 전략에 따르면, Basware는 20% - 4...
# ...                                                 ...
# 4841  런던 마켓워치 -- 은행주의 반등이 FTSE 100지수의 약세를 상쇄하지 못하면서 ...
# 4842  린쿠스키아의 맥주 판매량은 416만 리터로 6.5% 감소했으며 카우노 알루스의 맥주...
# 4843  영업이익은 2007년 68.8 mn에서 35.4 mn으로 떨어졌으며, 선박 판매 이...
# 4844  페이퍼 부문 순매출은 2008년 2분기 241.1 mn에서 2009년 2분기 221...
# 4845   핀란드에서의 판매는 1월에 10.5% 감소한 반면, 국외에서의 판매는 17% 감소했다.
#
# [4846 rows x 3 columns]

# %%
# finance_data_labeled = finance_data
# finance_data_labeled['labels'] = finance_data_labeled['labels'].replace('neutral',0).replace('negative',-1).replace('positive',1)
# finance_data

# %%
del finance_data_labeled['kor_sentence']
finance_data_labeled.head()
# Out:
#    labels                                           sentence
# 0       1  According to Gran, the company has no plans to...
# 1       1  Technopolis plans to develop in stages an area...
# 2       0  The international electronic industry company ...
# 3       2  With the new production plant the company woul...
# 4       2  According to the company's updated strategy fo...

# %%
finance_data_labeled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4846 entries, 0 to 4845
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   labels    4846 non-null   int32
#  1   sentence  4846 non-null   object
# dtypes: int32(1), object(1)
# memory usage: 56.9+ KB

# %%
print('결측값 여부 :',finance_data_labeled.isnull().values.any())
# Out:
# 결측값 여부 : False

# %%
print('sentence 열의 유니크한 값 :',finance_data_labeled['sentence'].nunique())
# Out:
# sentence 열의 유니크한 값 : 4838

# %%
duplicate = finance_data_labeled[finance_data_labeled.duplicated()] # unique data와 전체 data의 수가 맞지 않아 중복 제거

# %%
duplicate
# Out:
#       labels                                           sentence
# 1099       1  The issuer is solely responsible for the conte...
# 1416       1  The report profiles 614 companies including ma...
# 2396       1  Ahlstrom's share is quoted on the NASDAQ OMX H...
# 2567       1  SSH Communications Security Corporation is hea...
# 3094       1  Proha Plc ( Euronext :7327 ) announced today (...
# 3206       1  The company serves customers in various indust...

# %%
# 중복 제거
finance_data_labeled.drop_duplicates(subset=['sentence'], inplace=True)
print('총 샘플의 수 :',len(finance_data_labeled))
# Out:
# 총 샘플의 수 : 4838

# %%
finance_data_labeled['labels'].value_counts().plot(kind='bar') # 0:negative, 1:neutral, 2:positive
# Out:
# <Axes: xlabel='labels'>

# %%
print('레이블의 분포')
print(finance_data_labeled.groupby('labels').size().reset_index(name='count'))
# Out:
# 레이블의 분포
#    labels  count
# 0       0    604
# 1       1   2872
# 2       2   1362

# %%
print(f'중립의 비율 = {round(finance_data_labeled["labels"].value_counts()[1]/len(finance_data_labeled) * 100,3)}%')
print(f'긍정의 비율 = {round(finance_data_labeled["labels"].value_counts()[2]/len(finance_data_labeled) * 100,3)}%')
print(f'부정의 비율 = {round(finance_data_labeled["labels"].value_counts()[0]/len(finance_data_labeled) * 100,3)}%')
# Out:
# 중립의 비율 = 59.363%
# 긍정의 비율 = 28.152%
# 부정의 비율 = 12.484%

# %%
X_data = finance_data_labeled['sentence']
y_data = finance_data_labeled['labels']
print('본문의 개수: {}'.format(len(X_data)))
print('레이블의 개수: {}'.format(len(y_data)))
# Out:
# 본문의 개수: 4838
# 레이블의 개수: 4838

# %%
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.2, random_state=0, stratify=y_data)

# %%
sorted(X_test.index)
# Out:
# [0,
#  22,
#  27,
#  31,
#  38,
#  39,
#  40,
#  41,
#  43,
#  44,
#  49,
#  53,
#  54,
#  56,
#  59,
#  64,
#  73,
#  87,
#  90,
#  91,
#  108,
#  109,
#  115,
#  131,
#  138,
#  143,
#  145,
#  153,
#  157,
#  162,
#  176,
#  186,
#  187,
#  198,
#  209,
#  213,
#  218,
#  228,
#  233,
#  234,
#  237,
#  238,
#  240,
#  244,
#  252,
#  256,
#  258,
#  259,
#  279,
#  282,
#  287,
#  288,
#  298,
#  302,
#  313,
#  317,
#  320,
#  333,
#  337,
#  341,
#  343,
#  344,
#  346,
#  354,
#  389,
#  394,
#  398,
#  402,
#  408,
#  409,
#  416,
#  422,
#  423,
#  428,
#  431,
#  434,
#  438,
#  450,
#  451,
#  453,
#  454,
#  460,
#  464,
#  468,
#  470,
#  473,
#  479,
#  484,
#  487,
#  488,
#  494,
#  495,
#  496,
#  502,
#  504,
#  505,
#  511,
#  512,
#  515,
#  521,
#  525,
#  527,
#  531,
#  536,
#  538,
#  541,
#  548,
#  561,
#  566,
#  570,
#  575,
#  584,
#  588,
#  591,
#  594,
#  599,
#  608,
#  610,
#  613,
#  618,
#  620,
#  623,
#  633,
#  638,
#  643,
#  645,
#  648,
#  651,
#  653,
#  661,
#  664,
#  669,
#  671,
#  679,
#  683,
#  685,
#  690,
#  692,
#  698,
#  703,
#  705,
#  711,
#  716,
#  726,
#  730,
#  731,
#  735,
#  751,
#  754,
#  756,
#  764,
#  768,
#  771,
#  772,
#  778,
#  782,
#  785,
#  807,
#  825,
#  826,
#  827,
#  843,
#  847,
#  848,
#  852,
#  855,
#  858,
#  866,
#  871,
#  872,
#  873,
#  878,
#  881,
#  882,
#  887,
#  889,
#  890,
#  892,
#  895,
#  897,
#  906,
#  910,
#  914,
#  918,
#  921,
#  923,
#  924,
#  926,
#  927,
#  936,
#  955,
#  960,
#  961,
#  962,
#  966,
#  968,
#  974,
#  981,
#  982,
#  988,
#  991,
#  1005,
#  1007,
#  1010,
#  1013,
#  1018,
#  1039,
#  1040,
#  1041,
#  1052,
#  1055,
#  1061,
#  1068,
#  1070,
#  1072,
#  1075,
#  1079,
#  1083,
#  1094,
#  1102,
#  1103,
#  1105,
#  1114,
#  1124,
#  1126,
#  1129,
#  1140,
#  1141,
#  1145,
#  1168,
#  1171,
#  1179,
#  1182,
#  1192,
#  1198,
#  1214,
#  1219,
#  1221,
#  1224,
#  1229,
#  1230,
#  1235,
#  1240,
#  1242,
#  1243,
#  1252,
#  1260,
#  1267,
#  1269,
#  1274,
#  1276,
#  1289,
#  1293,
#  1297,
#  1298,
#  1309,
#  1310,
#  1312,
#  1319,
#  1321,
#  1322,
#  1325,
#  1329,
#  1332,
#  1336,
#  1337,
#  1338,
#  1353,
#  1355,
#  1360,
#  1384,
#  1386,
#  1387,
#  1396,
#  1400,
#  1402,
#  1407,
#  1417,
#  1418,
#  1419,
#  1426,
#  1437,
#  1439,
#  1448,
#  1449,
#  1452,
#  1455,
#  1461,
#  1474,
#  1476,
#  1477,
#  1484,
#  1487,
#  1503,
#  1506,
#  1520,
#  1523,
#  1525,
#  1526,
#  1527,
#  1528,
#  1532,
#  1537,
#  1539,
#  1540,
#  1541,
#  1542,
#  1543,
#  1547,
#  1563,
#  1568,
#  1570,
#  1577,
#  1581,
#  1583,
#  1591,
#  1601,
#  1605,
#  1616,
#  1619,
#  1621,
#  1623,
#  1625,
#  1634,
#  1660,
#  1665,
#  1674,
#  1675,
#  1680,
#  1682,
#  1691,
#  1692,
#  1701,
#  1708,
#  1712,
#  1718,
#  1724,
#  1726,
#  1727,
#  1734,
#  1739,
#  1743,
#  1744,
#  1746,
#  1747,
#  1748,
#  1750,
#  1752,
#  1753,
#  1755,
#  1761,
#  1770,
#  1771,
#  1772,
#  1780,
#  1781,
#  1785,
#  1786,
#  1789,
#  1794,
#  1800,
#  1805,
#  1810,
#  1811,
#  1816,
#  1818,
#  1821,
#  1831,
#  1833,
#  1846,
#  1849,
#  1851,
#  1870,
#  1875,
#  1885,
#  1899,
#  1903,
#  1905,
#  1909,
#  1913,
#  1915,
#  1917,
#  1932,
#  1944,
#  1950,
#  1962,
#  1965,
#  1969,
#  1970,
#  1973,
#  1982,
#  1994,
#  1999,
#  2009,
#  2013,
#  2024,
#  2027,
#  2031,
#  2042,
#  2043,
#  2045,
#  2051,
#  2052,
#  2057,
#  2058,
#  2060,
#  2064,
#  2071,
#  2078,
#  2085,
#  2087,
#  2088,
#  2102,
#  2105,
#  2122,
#  2124,
#  2125,
#  2126,
#  2129,
#  2132,
#  2133,
#  2136,
#  2139,
#  2140,
#  2145,
#  2147,
#  2158,
#  2179,
#  2191,
#  2217,
#  2220,
#  2228,
#  2232,
#  2240,
#  2246,
#  2247,
#  2252,
#  2257,
#  2268,
#  2280,
#  2281,
#  2286,
#  2289,
#  2290,
#  2292,
#  2299,
#  2315,
#  2327,
#  2330,
#  2331,
#  2336,
#  2355,
#  2357,
#  2359,
#  2363,
#  2365,
#  2371,
#  2372,
#  2376,
#  2380,
#  2392,
#  2395,
#  2406,
#  2412,
#  2416,
#  2420,
#  2427,
#  2429,
#  2430,
#  2431,
#  2436,
#  2439,
#  2440,
#  2461,
#  2465,
#  2468,
#  2469,
#  2474,
#  2479,
#  2488,
#  2489,
#  2491,
#  2494,
#  2497,
#  2500,
#  2511,
#  2514,
#  2521,
#  2526,
#  2530,
#  2535,
#  2541,
#  2543,
#  2547,
#  2564,
#  2589,
#  2601,
#  2604,
#  2605,
#  2607,
#  2613,
#  2614,
#  2621,
#  2622,
#  2623,
#  2624,
#  2625,
#  2628,
#  2636,
#  2637,
#  2651,
#  2660,
#  2662,
#  2666,
#  2678,
#  2683,
#  2687,
#  2693,
#  2701,
#  2709,
#  2712,
#  2719,
#  2720,
#  2722,
#  2724,
#  2725,
#  2726,
#  2727,
#  2734,
#  2743,
#  2749,
#  2754,
#  2756,
#  2757,
#  2758,
#  2760,
#  2762,
#  2763,
#  2765,
#  2766,
#  2783,
#  2797,
#  2807,
#  2810,
#  2812,
#  2814,
#  2828,
#  2830,
#  2832,
#  2838,
#  2840,
#  2847,
#  2848,
#  2852,
#  2854,
#  2858,
#  2866,
#  2872,
#  2879,
#  2880,
#  2892,
#  2896,
#  2910,
#  2911,
#  2919,
#  2921,
#  2933,
#  2935,
#  2940,
#  2947,
#  2948,
#  2949,
#  2955,
#  2956,
#  2958,
#  2964,
#  2965,
#  2966,
#  2971,
#  2972,
#  2973,
#  2977,
#  2981,
#  2982,
#  2984,
#  2985,
#  2996,
#  3001,
#  3003,
#  3007,
#  3012,
#  3019,
#  3026,
#  3035,
#  3039,
#  3040,
#  3043,
#  3060,
#  3062,
#  3069,
#  3077,
#  3078,
#  3085,
#  3087,
#  3088,
#  3089,
#  3092,
#  3100,
#  3102,
#  3104,
#  3114,
#  3131,
#  3140,
#  3145,
#  3146,
#  3147,
#  3153,
#  3162,
#  3163,
#  3165,
#  3169,
#  3173,
#  3175,
#  3176,
#  3178,
#  3180,
#  3182,
#  3187,
#  3199,
#  3209,
#  3215,
#  3224,
#  3225,
#  3227,
#  3229,
#  3233,
#  3240,
#  3242,
#  3244,
#  3245,
#  3253,
#  3261,
#  3262,
#  3274,
#  3275,
#  3280,
#  3282,
#  3291,
#  3293,
#  3296,
#  3298,
#  3301,
#  3305,
#  3308,
#  3310,
#  3311,
#  3317,
#  3320,
#  3330,
#  3334,
#  3343,
#  3345,
#  3346,
#  3359,
#  3361,
#  3370,
#  3371,
#  3377,
#  3382,
#  3390,
#  3393,
#  3395,
#  3396,
#  3397,
#  3398,
#  3401,
#  3408,
#  3421,
#  3432,
#  3437,
#  3444,
#  3445,
#  3453,
#  3459,
#  3462,
#  3468,
#  3473,
#  3474,
#  3483,
#  3503,
#  3508,
#  3510,
#  3517,
#  3519,
#  3526,
#  3530,
#  3535,
#  3540,
#  3542,
#  3551,
#  3561,
#  3562,
#  3564,
#  3567,
#  3571,
#  3576,
#  3580,
#  3584,
#  3592,
#  3606,
#  3613,
#  3615,
#  3624,
#  3625,
#  3645,
#  3648,
#  3656,
#  3668,
#  3669,
#  3671,
#  3678,
#  3681,
#  3684,
#  3685,
#  3687,
#  3698,
#  3700,
#  3704,
#  3706,
#  3709,
#  3712,
#  3716,
#  3721,
#  3729,
#  3732,
#  3734,
#  3737,
#  3746,
#  3749,
#  3752,
#  3763,
#  3764,
#  3770,
#  3775,
#  3779,
#  3785,
#  3791,
#  3792,
#  3793,
#  3794,
#  3797,
#  3800,
#  3814,
#  3815,
#  3819,
#  3820,
#  3822,
#  3829,
#  3839,
#  3844,
#  3846,
#  3849,
#  3853,
#  3858,
#  3859,
#  3860,
#  3863,
#  3872,
#  3878,
#  3880,
#  3890,
#  3891,
#  3893,
#  3896,
#  3897,
#  3899,
#  3903,
#  3907,
#  3913,
#  3917,
#  3919,
#  3924,
#  3927,
#  3931,
#  3933,
#  3939,
#  3942,
#  3946,
#  3949,
#  3952,
#  3956,
#  3960,
#  3963,
#  3965,
#  3970,
#  3973,
#  3979,
#  3982,
#  3987,
#  3991,
#  3993,
#  3997,
#  4000,
#  4004,
#  4006,
#  4007,
#  4008,
#  4024,
#  4028,
#  4029,
#  4033,
#  4046,
#  4053,
#  4058,
#  4061,
#  4064,
#  4066,
#  4067,
#  4068,
#  4076,
#  4080,
#  4082,
#  4084,
#  4086,
#  4098,
#  4104,
#  4115,
#  4123,
#  4124,
#  4126,
#  4127,
#  4128,
#  4130,
#  4131,
#  4134,
#  4137,
#  4144,
#  4146,
#  4153,
#  4158,
#  4159,
#  4161,
#  4164,
#  4167,
#  4171,
#  4189,
#  4198,
#  4200,
#  4204,
#  4229,
#  4230,
#  4231,
#  4232,
#  4246,
#  4254,
#  4265,
#  4272,
#  4276,
#  4280,
#  4286,
#  4291,
#  4293,
#  4296,
#  4298,
#  4301,
#  4310,
#  4311,
#  4315,
#  4317,
#  4318,
#  4320,
#  4321,
#  4325,
#  4326,
#  4338,
#  4339,
#  4342,
#  4349,
#  4354,
#  4356,
#  4367,
#  4371,
#  4375,
#  4377,
#  4379,
#  4382,
#  4388,
#  4390,
#  4393,
#  4394,
#  4396,
#  4398,
#  4407,
#  4409,
#  4415,
#  4418,
#  4425,
#  4428,
#  4432,
#  4439,
#  4463,
#  4472,
#  4483,
#  4494,
#  4507,
#  4508,
#  4513,
#  4518,
#  4522,
#  4523,
#  4528,
#  4537,
#  4538,
#  4539,
#  4541,
#  4545,
#  4552,
#  4553,
#  4558,
#  4560,
#  4561,
#  4563,
#  4567,
#  4577,
#  4582,
#  4584,
#  4588,
#  4589,
#  4598,
#  4607,
#  4608,
#  4625,
#  4626,
#  4629,
#  4641,
#  4648,
#  4649,
#  4660,
#  4662,
#  4666,
#  4668,
#  4677,
#  4690,
#  4704,
#  4706,
#  4707,
#  4728,
#  4730,
#  4750,
#  4752,
#  4755,
#  4757,
#  4761,
#  4762,
#  4768,
#  4769,
#  4785,
#  4786,
#  4791,
#  4796,
#  4799,
#  4800,
#  4805,
#  4806,
#  4812,
#  4814,
#  4827,
#  4832]

# %%
len(X_test)
# Out:
# 968

# %%
len(pd.unique(X_test.index))
# Out:
# 968

# %%
print('훈련 샘플의 개수 :', len(X_train))
print('테스트 샘플의 개수 :', len(X_test))
# Out:
# 훈련 샘플의 개수 : 3870
# 테스트 샘플의 개수 : 968

# %%
print('--------훈련 데이터의 비율-----------')
print(f'중립 = {round(y_train.value_counts()[1]/len(y_train) * 100,3)}%')
print(f'긍정 = {round(y_train.value_counts()[2]/len(y_train) * 100,3)}%')
print(f'부정 = {round(y_train.value_counts()[0]/len(y_train) * 100,3)}%')
# Out:
# --------훈련 데이터의 비율-----------
# 중립 = 59.354%
# 긍정 = 28.165%
# 부정 = 12.481%

# %%
print('--------테스트 데이터의 비율-----------')
print(f'중립 = {round(y_test.value_counts()[0]/len(y_test) * 100,3)}%')
print(f'긍정 = {round(y_test.value_counts()[1]/len(y_test) * 100,3)}%')
print(f'부정 = {round(y_test.value_counts()[2]/len(y_test) * 100,3)}%')
# Out:
# --------테스트 데이터의 비율-----------
# 중립 = 12.5%
# 긍정 = 59.401%
# 부정 = 28.099%

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)
X_train_encoded = tokenizer.texts_to_sequences(X_train)
X_test_encoded = tokenizer.texts_to_sequences(X_test)
print(X_train_encoded[:5])
print(X_test_encoded[:5])
# Out:
# [[197, 2, 1, 1585, 10, 18, 3, 37], [754, 1792, 696, 15, 286, 1, 259, 2, 14, 1793, 1396, 45, 5, 21, 275, 1396, 525, 4441, 49, 1, 37, 93, 3069, 1397, 13, 19, 12, 560], [4442, 146, 2, 332, 10, 1269, 6, 421, 2, 43, 36, 71, 43, 38, 82, 61, 7, 68, 22, 1, 169, 323, 367, 12, 238, 279, 53], [3070, 136, 659, 33, 3071, 17, 1, 146, 2, 332, 34, 422, 2, 8, 24, 56, 27, 60, 9, 8, 43, 215, 27, 280, 95, 526, 183, 12, 130, 131, 51], [3, 266, 21, 755, 28, 402, 1060, 1586, 4, 89, 7, 4443, 4, 403, 10, 804, 4444, 1586, 28, 10, 18, 1143, 3, 6, 221, 1587, 2052, 1398, 217, 2053, 4, 1794, 3, 6, 24, 35, 4445, 204]]
# [[726, 232, 55, 132, 173, 234, 178, 298, 68, 22, 178, 724, 1010, 726, 65, 735, 7, 16, 1250, 132, 807, 6, 81, 2, 2146, 57, 47, 65, 2, 726, 232, 55, 64, 72, 735, 7, 16, 1, 80, 132, 807], [42, 30, 33, 8, 63, 23, 69, 293, 11, 8, 2968, 62, 23], [159, 32, 1, 13, 1071, 14, 369, 5, 203, 63, 27, 3429, 8, 36, 44, 11, 52, 24, 27, 3429, 3, 277], [42, 30, 7, 1, 248, 274, 48, 107, 11, 1427, 52, 31, 201, 29, 25, 107, 11, 63, 31, 20, 75, 5, 1, 97, 48, 3, 114], [74, 1, 1696, 2935, 46, 1, 5074, 2, 1, 6798, 229, 4, 3373, 415, 1978, 16, 1574, 240, 11, 450]]

# %%
word_to_index = tokenizer.word_index
vocab_size = len(word_to_index) + 1
print(vocab_size)
# Out:
# 9430

# %%
print('본문의 최대 길이 :',max(len(sent) for sent in X_train))
print('본문의 평균 길이 :',sum(map(len, X_train))/len(X_train))
plt.hist([len(sent) for sent in X_train], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 본문의 최대 길이 : 302
# 본문의 평균 길이 : 126.4937984496124

# %%
max_len = 302

# %%
X_train_encoded = pad_sequences(X_train_encoded, maxlen=max_len)
X_test_encoded = pad_sequences(X_test_encoded, maxlen=max_len)

# %%
X_train_encoded.shape
# Out:
# (3870, 302)

# %%
X_test_encoded.shape
# Out:
# (968, 302)

# %%
from tensorflow.keras.layers import Embedding, Dense, LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
embedding_dim = 64
hidden_units = 64
num_classes = 3

model = Sequential()
model.add(Embedding(vocab_size, embedding_dim))
model.add(LSTM(hidden_units))
model.add(Dense(num_classes, activation='softmax'))

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
# mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])
history = model.fit(X_train_encoded, y_train, epochs=15, batch_size=32, validation_split=0.2)
model.save("model1.h5")
# tf.saved_model.save(model)
# Out:
# Epoch 1/15
# 97/97 [==============================] - 5s 46ms/step - loss: 0.8770 - acc: 0.6111 - val_loss: 0.7762 - val_acc: 0.6563
# Epoch 2/15
# 97/97 [==============================] - 4s 44ms/step - loss: 0.6595 - acc: 0.7171 - val_loss: 0.7049 - val_acc: 0.7041
# Epoch 3/15
# 97/97 [==============================] - 5s 47ms/step - loss: 0.3916 - acc: 0.8391 - val_loss: 0.7866 - val_acc: 0.6964
# Epoch 4/15
# 97/97 [==============================] - 4s 45ms/step - loss: 0.2047 - acc: 0.9273 - val_loss: 0.8655 - val_acc: 0.7326
# Epoch 5/15
# 97/97 [==============================] - 4s 45ms/step - loss: 0.0898 - acc: 0.9745 - val_loss: 1.0205 - val_acc: 0.7326
# Epoch 6/15
# 97/97 [==============================] - 4s 44ms/step - loss: 0.0582 - acc: 0.9839 - val_loss: 0.8719 - val_acc: 0.7016
# Epoch 7/15
# 97/97 [==============================] - 4s 44ms/step - loss: 0.0485 - acc: 0.9903 - val_loss: 1.1651 - val_acc: 0.7222
# Epoch 8/15
# 97/97 [==============================] - 4s 44ms/step - loss: 0.0176 - acc: 0.9971 - val_loss: 1.2770 - val_acc: 0.7235
# Epoch 9/15
# 97/97 [==============================] - 4s 43ms/step - loss: 0.0107 - acc: 0.9977 - val_loss: 1.3804 - val_acc: 0.7132
# Epoch 10/15
# 97/97 [==============================] - 4s 43ms/step - loss: 0.0126 - acc: 0.9981 - val_loss: 1.3124 - val_acc: 0.7261
# Epoch 11/15
# 97/97 [==============================] - 4s 44ms/step - loss: 0.0220 - acc: 0.9952 - val_loss: 1.2976 - val_acc: 0.7287
# Epoch 12/15
# 97/97 [==============================] - 4s 43ms/step - loss: 0.0258 - acc: 0.9926 - val_loss: 1.2563 - val_acc: 0.7339
# Epoch 13/15
# 97/97 [==============================] - 4s 44ms/step - loss: 0.0114 - acc: 0.9981 - val_loss: 1.3430 - val_acc: 0.7429
# Epoch 14/15
# 97/97 [==============================] - 4s 44ms/step - loss: 0.0070 - acc: 0.9984 - val_loss: 1.4393 - val_acc: 0.7390
# Epoch 15/15
# 97/97 [==============================] - 4s 44ms/step - loss: 0.0110 - acc: 0.9964 - val_loss: 1.4424 - val_acc: 0.7093
# C:\Users\chan\anaconda3\envs\ng\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
#  callbacks=[es, mc], -> history - model.fit 안에 매개변수로 추가하기

# %%
loaded_model = load_model('model1.h5')
print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(X_test_encoded, y_test)[1]))
# Out:
# 31/31 [==============================] - 1s 13ms/step - loss: 1.4319 - acc: 0.7035
#
#  테스트 정확도: 0.7035

# %% [markdown]
# ### 우리가 사용할 데이터 돌려보기

# %%
dataframes = []

for i in range(1, 35):
    filename = f"{i}.txt"
    file_path = os.path.join("news/", filename)
    try:
        with open(file_path, 'r') as file:
            content = file.read()
            df = pd.DataFrame({'content': [content]})
            dataframes.append(df)
    except FileNotFoundError:
        print(f"File {filename} not found. Skipping...")

# 모든 데이터프레임을 하나로 합칩니다.
result_df = pd.concat(dataframes, ignore_index=True)

# 결과를 확인합니다.
print(result_df)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[37], line 8
#       6 try:
#       7     with open(file_path, 'r') as file:
# ----> 8         content = file.read()
#       9         df = pd.DataFrame({'content': [content]})
#      10         dataframes.append(df)
#
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xe2 in position 2254: illegal multibyte sequence

# %%
(len(max(result_df['content'])))

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(result_df['content'])
X_test_encoded = tokenizer.texts_to_sequences(result_df['content'])
print(X_test_encoded[:5])

# %%
word_to_index = tokenizer.word_index
vocab_size = len(word_to_index) + 1
print(vocab_size)

# %%
print('본문의 최대 길이 :',max(len(sent) for sent in result_df['content']))
print('본문의 평균 길이 :',sum(map(len, result_df['content']))/len(result_df['content']))
plt.hist([len(sent) for sent in result_df['content']], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()

# %%
max_len = 3878

# %%
X_test_encoded = pad_sequences(X_test_encoded, maxlen=max_len)

# %%
predicted_results = model.predict(X_test_encoded)

print(predicted_results)

# %%
binary_matrix = np.zeros_like(predicted_results)
binary_matrix[np.arange(len(predicted_results)), predicted_results.argmax(axis=1)] = 1
print(binary_matrix)

# %%
csv_file_path = "predict.csv"

# NumPy 배열을 CSV 파일로 저장
np.savetxt(csv_file_path, binary_matrix, delimiter=",", fmt='%d')
